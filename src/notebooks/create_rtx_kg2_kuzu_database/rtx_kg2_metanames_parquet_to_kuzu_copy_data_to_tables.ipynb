# %% [markdown]
# # Generate RTX-KG2 Metanames Parquet to Kuzu - Copy Data to Tables
#
# Note: may require large amount of memory to successfully perform ingest.

# %%
import gzip
import json
import pathlib
import shutil
import time
from functools import partial
from typing import Any, Dict, Generator, List, Literal, Optional

import awkward as ak
import duckdb
import ijson
import kuzu
import pyarrow as pa
import requests
from genson import SchemaBuilder
from pyarrow import parquet

from notebooks.rtx_kg2_functions import (
    count_items_under_top_level_name,
    drop_table_if_exists,
    find_top_level_names,
    generate_cypher_table_create_stmt_from_parquet_file,
    kz_execute_with_retries,
    parse_items_by_topmost_item_name,
    parse_metadata_by_object_name,
)

# %%
# set data to be used throughout notebook
chunk_size = 500000
data_dir = "../data"
parquet_dir = f"{data_dir}/"
source_data_url = "https://github.com/ncats/translator-lfs-artifacts/raw/main/files/kg2c_lite_2.8.4.json.gz"
target_extracted_sample_data = (
    f"{data_dir}/{pathlib.Path(source_data_url).name.replace('.json.gz', '.json')}"
)
parquet_dir = target_extracted_sample_data.replace(".json", ".full.dataset.parquet")
parquet_metanames_dir = target_extracted_sample_data.replace(
    ".json", ".full.with-metanames.dataset.parquet"
)
kuzu_dir = target_extracted_sample_data.replace(
    ".json", ".full.with-metanames.dataset.kuzu"
)
target_extracted_sample_data_schema_file = target_extracted_sample_data.replace(
    ".json", ".schema.json"
)
dataset_name_to_cypher_table_type_map = {"nodes": "node", "edges": "rel"}
print(f"Kuzu dir: {kuzu_dir}")
# Out:
# Kuzu dir: ../data/kg2c_lite_2.8.4.full.with-metanames.dataset.kuzu

# %%
# init a Kuzu database and connection
db = kuzu.Database(f"{kuzu_dir}")
kz_conn = kuzu.Connection(db)

# %%
# note: we provide specific ordering here to ensure nodes are created before edges
table_count = 1
sub_table_count = 1
for path in [f"{parquet_metanames_dir}/nodes", f"{parquet_metanames_dir}/edges"]:

    decoded_type = dataset_name_to_cypher_table_type_map[pathlib.Path(path).name]
    print(f"Working on kuzu ingest of parquet dataset: {path} ")
    for table in pathlib.Path(path).glob("*"):
        table_name = table.name
        if decoded_type == "node":
            # uses wildcard functionality for all files under parquet dataset dir
            # see: https://kuzudb.com/docusaurus/data-import/csv-import#copy-from-multiple-csv-files-to-a-single-table
            ingest_stmt = f'COPY {table_name} FROM "{table}/*.parquet"'
            print(ingest_stmt)
            table_count += 1
            print(f"Table count: {table_count}")
            kz_execute_with_retries(kz_conn=kz_conn, kz_stmt=ingest_stmt)
        elif decoded_type == "rel":
            rel_node_pairs = list(pathlib.Path(table).glob("*"))

            sub_table_count = 1
            for rel_node_pair in rel_node_pairs:
                rel_node_pair_name = rel_node_pair.name

                ingest_stmt = (
                    f'COPY {table_name} FROM "{rel_node_pair}/*.parquet"'
                    if len(rel_node_pairs) == 1
                    else f'COPY {table_name}_{rel_node_pair_name} FROM "{rel_node_pair}/*.parquet"'
                )
                print(ingest_stmt)
                print(f"Table count: {table_count}, Sub-table count: {sub_table_count}")
                sub_table_count += 1
                kz_execute_with_retries(kz_conn=kz_conn, kz_stmt=ingest_stmt)

            table_count += 1
print("Finished running Kuzu COPY statements.")
# Out:
# Working on kuzu ingest of parquet dataset: ../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes
# COPY MolecularActivity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/MolecularActivity/*.parquet"
# Table count: 2
# COPY Behavior FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Behavior/*.parquet"
# Table count: 3
# COPY OrganismTaxon FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/OrganismTaxon/*.parquet"
# Table count: 4
# COPY GeographicLocation FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/GeographicLocation/*.parquet"
# Table count: 5
# COPY ClinicalIntervention FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/ClinicalIntervention/*.parquet"
# Table count: 6
# COPY BiologicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/BiologicalEntity/*.parquet"
# Table count: 7
# COPY EnvironmentalProcess FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/EnvironmentalProcess/*.parquet"
# Table count: 8
# COPY OrganismalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/OrganismalEntity/*.parquet"
# Table count: 9
# COPY Disease FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Disease/*.parquet"
# Table count: 10
# COPY PhysicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/PhysicalEntity/*.parquet"
# Table count: 11
# COPY RNAProduct FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/RNAProduct/*.parquet"
# Table count: 12
# COPY ChemicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/ChemicalEntity/*.parquet"
# Table count: 13
# COPY EnvironmentalFeature FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/EnvironmentalFeature/*.parquet"
# Table count: 14
# COPY Publication FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Publication/*.parquet"
# Table count: 15
# COPY IndividualOrganism FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/IndividualOrganism/*.parquet"
# Table count: 16
# COPY Exon FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Exon/*.parquet"
# Table count: 17
# COPY BiologicalProcess FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/BiologicalProcess/*.parquet"
# Table count: 18
# COPY ProteinDomain FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/ProteinDomain/*.parquet"
# Table count: 19
# COPY NamedThing FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/NamedThing/*.parquet"
# Table count: 20
# COPY PopulationOfIndividualOrganisms FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/PopulationOfIndividualOrganisms/*.parquet"
# Table count: 21
# COPY CellLine FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/CellLine/*.parquet"
# Table count: 22
# COPY Activity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Activity/*.parquet"
# Table count: 23
# COPY GeneticInheritance FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/GeneticInheritance/*.parquet"
# Table count: 24
# COPY AnatomicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/AnatomicalEntity/*.parquet"
# Table count: 25
# COPY Transcript FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Transcript/*.parquet"
# Table count: 26
# COPY MolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/MolecularMixture/*.parquet"
# Table count: 27
# COPY Protein FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Protein/*.parquet"
# Table count: 28
# COPY ComplexMolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/ComplexMolecularMixture/*.parquet"
# Table count: 29
# COPY PathologicalProcess FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/PathologicalProcess/*.parquet"
# Table count: 30
# COPY InformationContentEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/InformationContentEntity/*.parquet"
# Table count: 31
# COPY Agent FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Agent/*.parquet"
# Table count: 32
# COPY Phenomenon FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Phenomenon/*.parquet"
# Table count: 33
# COPY MaterialSample FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/MaterialSample/*.parquet"
# Table count: 34
# COPY GeneFamily FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/GeneFamily/*.parquet"
# Table count: 35
# COPY NucleicAcidEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/NucleicAcidEntity/*.parquet"
# Table count: 36
# COPY Gene FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Gene/*.parquet"
# Table count: 37
# COPY BehavioralFeature FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/BehavioralFeature/*.parquet"
# Table count: 38
# COPY NoncodingRNAProduct FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/NoncodingRNAProduct/*.parquet"
# Table count: 39
# COPY ProteinFamily FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/ProteinFamily/*.parquet"
# Table count: 40
# COPY GrossAnatomicalStructure FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/GrossAnatomicalStructure/*.parquet"
# Table count: 41
# COPY ClinicalAttribute FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/ClinicalAttribute/*.parquet"
# Table count: 42
# COPY Cell FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Cell/*.parquet"
# Table count: 43
# COPY LifeStage FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/LifeStage/*.parquet"
# Table count: 44
# COPY Procedure FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Procedure/*.parquet"
# Table count: 45
# COPY Cohort FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Cohort/*.parquet"
# Table count: 46
# COPY GenomicEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/GenomicEntity/*.parquet"
# Table count: 47
# COPY RetrievalSource FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/RetrievalSource/*.parquet"
# Table count: 48
# COPY PhenotypicFeature FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/PhenotypicFeature/*.parquet"
# Table count: 49
# COPY MicroRNA FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/MicroRNA/*.parquet"
# Table count: 50
# COPY OrganismAttribute FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/OrganismAttribute/*.parquet"
# Table count: 51
# COPY Food FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Food/*.parquet"
# Table count: 52
# COPY Treatment FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Treatment/*.parquet"
# Table count: 53
# COPY MolecularEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/MolecularEntity/*.parquet"
# Table count: 54
# COPY Pathway FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Pathway/*.parquet"
# Table count: 55
# COPY Device FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Device/*.parquet"
# Table count: 56
# COPY Drug FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Drug/*.parquet"
# Table count: 57
# COPY ChemicalMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/ChemicalMixture/*.parquet"
# Table count: 58
# COPY Polypeptide FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Polypeptide/*.parquet"
# Table count: 59
# COPY DiseaseOrPhenotypicFeature FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/DiseaseOrPhenotypicFeature/*.parquet"
# Table count: 60
# COPY CellularComponent FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/CellularComponent/*.parquet"
# Table count: 61
# COPY Event FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/Event/*.parquet"
# Table count: 62
# COPY SmallMolecule FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/SmallMolecule/*.parquet"
# Table count: 63
# COPY PhysiologicalProcess FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/nodes/PhysiologicalProcess/*.parquet"
# Table count: 64
# Working on kuzu ingest of parquet dataset: ../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges
# COPY produces_GrossAnatomicalStructure_Gene FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GrossAnatomicalStructure_Gene/*.parquet"
# Table count: 64, Sub-table count: 1
# COPY produces_Protein_GrossAnatomicalStructure FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Protein_GrossAnatomicalStructure/*.parquet"
# Table count: 64, Sub-table count: 2
# COPY produces_BiologicalEntity_MolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/BiologicalEntity_MolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 3
# COPY produces_CellularComponent_CellularComponent FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/CellularComponent_CellularComponent/*.parquet"
# Table count: 64, Sub-table count: 4
# COPY produces_Cell_NamedThing FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Cell_NamedThing/*.parquet"
# Table count: 64, Sub-table count: 5
# COPY produces_CellularComponent_Drug FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/CellularComponent_Drug/*.parquet"
# Table count: 64, Sub-table count: 6
# COPY produces_InformationContentEntity_ComplexMolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/InformationContentEntity_ComplexMolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 7
# COPY produces_Disease_NucleicAcidEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Disease_NucleicAcidEntity/*.parquet"
# Table count: 64, Sub-table count: 8
# COPY produces_Protein_Polypeptide FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Protein_Polypeptide/*.parquet"
# Table count: 64, Sub-table count: 9
# COPY produces_MolecularActivity_Gene FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/MolecularActivity_Gene/*.parquet"
# Table count: 64, Sub-table count: 10
# COPY produces_Protein_ChemicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Protein_ChemicalEntity/*.parquet"
# Table count: 64, Sub-table count: 11
# COPY produces_Protein_NucleicAcidEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Protein_NucleicAcidEntity/*.parquet"
# Table count: 64, Sub-table count: 12
# COPY produces_GeneticInheritance_OrganismTaxon FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GeneticInheritance_OrganismTaxon/*.parquet"
# Table count: 64, Sub-table count: 13
# COPY produces_Cell_Protein FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Cell_Protein/*.parquet"
# Table count: 64, Sub-table count: 14
# COPY produces_BiologicalEntity_ChemicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/BiologicalEntity_ChemicalEntity/*.parquet"
# Table count: 64, Sub-table count: 15
# COPY produces_ChemicalEntity_InformationContentEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/ChemicalEntity_InformationContentEntity/*.parquet"
# Table count: 64, Sub-table count: 16
# COPY produces_Disease_ComplexMolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Disease_ComplexMolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 17
# COPY produces_Behavior_SmallMolecule FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Behavior_SmallMolecule/*.parquet"
# Table count: 64, Sub-table count: 18
# COPY produces_BiologicalProcess_SmallMolecule FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/BiologicalProcess_SmallMolecule/*.parquet"
# Table count: 64, Sub-table count: 19
# COPY produces_PhysiologicalProcess_Cohort FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/PhysiologicalProcess_Cohort/*.parquet"
# Table count: 64, Sub-table count: 20
# COPY produces_Cell_SmallMolecule FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Cell_SmallMolecule/*.parquet"
# Table count: 64, Sub-table count: 21
# COPY produces_PhenotypicFeature_Cohort FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/PhenotypicFeature_Cohort/*.parquet"
# Table count: 64, Sub-table count: 22
# COPY produces_SmallMolecule_AnatomicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/SmallMolecule_AnatomicalEntity/*.parquet"
# Table count: 64, Sub-table count: 23
# COPY produces_Cohort_Device FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Cohort_Device/*.parquet"
# Table count: 64, Sub-table count: 24
# COPY produces_Cell_InformationContentEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Cell_InformationContentEntity/*.parquet"
# Table count: 64, Sub-table count: 25
# COPY produces_GrossAnatomicalStructure_MolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GrossAnatomicalStructure_MolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 26
# COPY produces_ChemicalEntity_MolecularActivity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/ChemicalEntity_MolecularActivity/*.parquet"
# Table count: 64, Sub-table count: 27
# COPY produces_OrganismAttribute_AnatomicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/OrganismAttribute_AnatomicalEntity/*.parquet"
# Table count: 64, Sub-table count: 28
# COPY produces_Gene_SmallMolecule FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Gene_SmallMolecule/*.parquet"
# Table count: 64, Sub-table count: 29
# COPY produces_MolecularActivity_Cohort FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/MolecularActivity_Cohort/*.parquet"
# Table count: 64, Sub-table count: 30
# COPY produces_GeneticInheritance_NamedThing FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GeneticInheritance_NamedThing/*.parquet"
# Table count: 64, Sub-table count: 31
# COPY produces_MolecularActivity_ComplexMolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/MolecularActivity_ComplexMolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 32
# COPY produces_GenomicEntity_ComplexMolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GenomicEntity_ComplexMolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 33
# COPY produces_OrganismAttribute_Publication FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/OrganismAttribute_Publication/*.parquet"
# Table count: 64, Sub-table count: 34
# COPY produces_ChemicalEntity_MolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/ChemicalEntity_MolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 35
# COPY produces_GenomicEntity_CellularComponent FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GenomicEntity_CellularComponent/*.parquet"
# Table count: 64, Sub-table count: 36
# COPY produces_Drug_Publication FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Drug_Publication/*.parquet"
# Table count: 64, Sub-table count: 37
# COPY produces_OrganismTaxon_Publication FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/OrganismTaxon_Publication/*.parquet"
# Table count: 64, Sub-table count: 38
# COPY produces_GrossAnatomicalStructure_ChemicalMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GrossAnatomicalStructure_ChemicalMixture/*.parquet"
# Table count: 64, Sub-table count: 39
# COPY produces_PhysiologicalProcess_OrganismTaxon FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/PhysiologicalProcess_OrganismTaxon/*.parquet"
# Table count: 64, Sub-table count: 40
# COPY produces_OrganismAttribute_Cohort FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/OrganismAttribute_Cohort/*.parquet"
# Table count: 64, Sub-table count: 41
# COPY produces_ChemicalEntity_AnatomicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/ChemicalEntity_AnatomicalEntity/*.parquet"
# Table count: 64, Sub-table count: 42
# COPY produces_Agent_Agent FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Agent_Agent/*.parquet"
# Table count: 64, Sub-table count: 43
# COPY produces_Cohort_PhysiologicalProcess FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Cohort_PhysiologicalProcess/*.parquet"
# Table count: 64, Sub-table count: 44
# COPY produces_CellularComponent_Device FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/CellularComponent_Device/*.parquet"
# Table count: 64, Sub-table count: 45
# COPY produces_ChemicalEntity_DiseaseOrPhenotypicFeature FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/ChemicalEntity_DiseaseOrPhenotypicFeature/*.parquet"
# Table count: 64, Sub-table count: 46
# COPY produces_Protein_Cell FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Protein_Cell/*.parquet"
# Table count: 64, Sub-table count: 47
# COPY produces_GrossAnatomicalStructure_ComplexMolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GrossAnatomicalStructure_ComplexMolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 48
# COPY produces_Protein_Disease FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Protein_Disease/*.parquet"
# Table count: 64, Sub-table count: 49
# COPY produces_OrganismAttribute_MolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/OrganismAttribute_MolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 50
# COPY produces_MolecularMixture_OrganismTaxon FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/MolecularMixture_OrganismTaxon/*.parquet"
# Table count: 64, Sub-table count: 51
# COPY produces_GrossAnatomicalStructure_AnatomicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GrossAnatomicalStructure_AnatomicalEntity/*.parquet"
# Table count: 64, Sub-table count: 52
# COPY produces_NamedThing_Drug FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/NamedThing_Drug/*.parquet"
# Table count: 64, Sub-table count: 53
# COPY produces_OrganismAttribute_PhysiologicalProcess FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/OrganismAttribute_PhysiologicalProcess/*.parquet"
# Table count: 64, Sub-table count: 54
# COPY produces_Procedure_InformationContentEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Procedure_InformationContentEntity/*.parquet"
# Table count: 64, Sub-table count: 55
# COPY produces_OrganismTaxon_ComplexMolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/OrganismTaxon_ComplexMolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 56
# COPY produces_ClinicalAttribute_Gene FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/ClinicalAttribute_Gene/*.parquet"
# Table count: 64, Sub-table count: 57
# COPY produces_SmallMolecule_MolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/SmallMolecule_MolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 58
# COPY produces_Cohort_Procedure FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Cohort_Procedure/*.parquet"
# Table count: 64, Sub-table count: 59
# COPY produces_PhenotypicFeature_Gene FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/PhenotypicFeature_Gene/*.parquet"
# Table count: 64, Sub-table count: 60
# COPY produces_CellularComponent_NamedThing FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/CellularComponent_NamedThing/*.parquet"
# Table count: 64, Sub-table count: 61
# COPY produces_Phenomenon_Polypeptide FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Phenomenon_Polypeptide/*.parquet"
# Table count: 64, Sub-table count: 62
# COPY produces_PhysiologicalProcess_BiologicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/PhysiologicalProcess_BiologicalEntity/*.parquet"
# Table count: 64, Sub-table count: 63
# COPY produces_OrganismAttribute_Gene FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/OrganismAttribute_Gene/*.parquet"
# Table count: 64, Sub-table count: 64
# COPY produces_Activity_SmallMolecule FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Activity_SmallMolecule/*.parquet"
# Table count: 64, Sub-table count: 65
# COPY produces_ClinicalAttribute_AnatomicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/ClinicalAttribute_AnatomicalEntity/*.parquet"
# Table count: 64, Sub-table count: 66
# COPY produces_Protein_SmallMolecule FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Protein_SmallMolecule/*.parquet"
# Table count: 64, Sub-table count: 67
# COPY produces_PopulationOfIndividualOrganisms_Drug FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/PopulationOfIndividualOrganisms_Drug/*.parquet"
# Table count: 64, Sub-table count: 68
# COPY produces_Gene_ChemicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Gene_ChemicalEntity/*.parquet"
# Table count: 64, Sub-table count: 69
# COPY produces_NamedThing_ChemicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/NamedThing_ChemicalEntity/*.parquet"
# Table count: 64, Sub-table count: 70
# COPY produces_GrossAnatomicalStructure_Protein FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GrossAnatomicalStructure_Protein/*.parquet"
# Table count: 64, Sub-table count: 71
# COPY produces_AnatomicalEntity_GrossAnatomicalStructure FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/AnatomicalEntity_GrossAnatomicalStructure/*.parquet"
# Table count: 64, Sub-table count: 72
# COPY produces_InformationContentEntity_Device FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/InformationContentEntity_Device/*.parquet"
# Table count: 64, Sub-table count: 73
# COPY produces_Gene_Cell FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Gene_Cell/*.parquet"
# Table count: 64, Sub-table count: 74
# COPY produces_Behavior_Protein FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Behavior_Protein/*.parquet"
# Table count: 64, Sub-table count: 75
# COPY produces_GrossAnatomicalStructure_PhenotypicFeature FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GrossAnatomicalStructure_PhenotypicFeature/*.parquet"
# Table count: 64, Sub-table count: 76
# COPY produces_Agent_InformationContentEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Agent_InformationContentEntity/*.parquet"
# Table count: 64, Sub-table count: 77
# COPY produces_CellularComponent_BiologicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/CellularComponent_BiologicalEntity/*.parquet"
# Table count: 64, Sub-table count: 78
# COPY produces_MolecularActivity_InformationContentEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/MolecularActivity_InformationContentEntity/*.parquet"
# Table count: 64, Sub-table count: 79
# COPY produces_OrganismTaxon_PhysicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/OrganismTaxon_PhysicalEntity/*.parquet"
# Table count: 64, Sub-table count: 80
# COPY produces_PhysiologicalProcess_Cell FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/PhysiologicalProcess_Cell/*.parquet"
# Table count: 64, Sub-table count: 81
# COPY produces_BiologicalEntity_AnatomicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/BiologicalEntity_AnatomicalEntity/*.parquet"
# Table count: 64, Sub-table count: 82
# COPY produces_MolecularActivity_NamedThing FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/MolecularActivity_NamedThing/*.parquet"
# Table count: 64, Sub-table count: 83
# COPY produces_AnatomicalEntity_Polypeptide FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/AnatomicalEntity_Polypeptide/*.parquet"
# Table count: 64, Sub-table count: 84
# COPY produces_Activity_Cohort FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Activity_Cohort/*.parquet"
# Table count: 64, Sub-table count: 85
# COPY produces_Disease_Device FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Disease_Device/*.parquet"
# Table count: 64, Sub-table count: 86
# COPY produces_Activity_ChemicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Activity_ChemicalEntity/*.parquet"
# Table count: 64, Sub-table count: 87
# COPY produces_Phenomenon_NucleicAcidEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Phenomenon_NucleicAcidEntity/*.parquet"
# Table count: 64, Sub-table count: 88
# COPY produces_GenomicEntity_GenomicEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GenomicEntity_GenomicEntity/*.parquet"
# Table count: 64, Sub-table count: 89
# COPY produces_GenomicEntity_Gene FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GenomicEntity_Gene/*.parquet"
# Table count: 64, Sub-table count: 90
# COPY produces_BiologicalEntity_SmallMolecule FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/BiologicalEntity_SmallMolecule/*.parquet"
# Table count: 64, Sub-table count: 91
# COPY produces_AnatomicalEntity_GenomicEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/AnatomicalEntity_GenomicEntity/*.parquet"
# Table count: 64, Sub-table count: 92
# COPY produces_PhenotypicFeature_Protein FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/PhenotypicFeature_Protein/*.parquet"
# Table count: 64, Sub-table count: 93
# COPY produces_GeneticInheritance_Cohort FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GeneticInheritance_Cohort/*.parquet"
# Table count: 64, Sub-table count: 94
# COPY produces_OrganismTaxon_BiologicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/OrganismTaxon_BiologicalEntity/*.parquet"
# Table count: 64, Sub-table count: 95
# COPY produces_Cell_Drug FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Cell_Drug/*.parquet"
# Table count: 64, Sub-table count: 96
# COPY produces_GenomicEntity_Disease FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GenomicEntity_Disease/*.parquet"
# Table count: 64, Sub-table count: 97
# COPY produces_Phenomenon_AnatomicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Phenomenon_AnatomicalEntity/*.parquet"
# Table count: 64, Sub-table count: 98
# COPY produces_Disease_Disease FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Disease_Disease/*.parquet"
# Table count: 64, Sub-table count: 99
# COPY produces_Procedure_Disease FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Procedure_Disease/*.parquet"
# Table count: 64, Sub-table count: 100
# COPY produces_NucleicAcidEntity_Protein FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/NucleicAcidEntity_Protein/*.parquet"
# Table count: 64, Sub-table count: 101
# COPY produces_GenomicEntity_Polypeptide FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GenomicEntity_Polypeptide/*.parquet"
# Table count: 64, Sub-table count: 102
# COPY produces_Polypeptide_SmallMolecule FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Polypeptide_SmallMolecule/*.parquet"
# Table count: 64, Sub-table count: 103
# COPY produces_Cohort_Cell FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Cohort_Cell/*.parquet"
# Table count: 64, Sub-table count: 104
# COPY produces_MolecularMixture_CellularComponent FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/MolecularMixture_CellularComponent/*.parquet"
# Table count: 64, Sub-table count: 105
# COPY produces_Behavior_Cohort FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Behavior_Cohort/*.parquet"
# Table count: 64, Sub-table count: 106
# COPY produces_Procedure_Gene FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Procedure_Gene/*.parquet"
# Table count: 64, Sub-table count: 107
# COPY produces_NamedThing_BiologicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/NamedThing_BiologicalEntity/*.parquet"
# Table count: 64, Sub-table count: 108
# COPY produces_MolecularActivity_OrganismTaxon FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/MolecularActivity_OrganismTaxon/*.parquet"
# Table count: 64, Sub-table count: 109
# COPY produces_AnatomicalEntity_Cohort FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/AnatomicalEntity_Cohort/*.parquet"
# Table count: 64, Sub-table count: 110
# COPY produces_Drug_SmallMolecule FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Drug_SmallMolecule/*.parquet"
# Table count: 64, Sub-table count: 111
# COPY produces_ComplexMolecularMixture_MolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/ComplexMolecularMixture_MolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 112
# COPY produces_SmallMolecule_Polypeptide FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/SmallMolecule_Polypeptide/*.parquet"
# Table count: 64, Sub-table count: 113
# COPY produces_Activity_Publication FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Activity_Publication/*.parquet"
# Table count: 64, Sub-table count: 114
# COPY produces_Gene_PhysicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Gene_PhysicalEntity/*.parquet"
# Table count: 64, Sub-table count: 115
# COPY produces_PhenotypicFeature_Publication FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/PhenotypicFeature_Publication/*.parquet"
# Table count: 64, Sub-table count: 116
# COPY produces_CellularComponent_Protein FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/CellularComponent_Protein/*.parquet"
# Table count: 64, Sub-table count: 117
# COPY produces_PhysiologicalProcess_NucleicAcidEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/PhysiologicalProcess_NucleicAcidEntity/*.parquet"
# Table count: 64, Sub-table count: 118
# COPY produces_InformationContentEntity_GenomicEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/InformationContentEntity_GenomicEntity/*.parquet"
# Table count: 64, Sub-table count: 119
# COPY produces_InformationContentEntity_InformationContentEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/InformationContentEntity_InformationContentEntity/*.parquet"
# Table count: 64, Sub-table count: 120
# COPY produces_InformationContentEntity_PhenotypicFeature FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/InformationContentEntity_PhenotypicFeature/*.parquet"
# Table count: 64, Sub-table count: 121
# COPY produces_GeneticInheritance_ChemicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GeneticInheritance_ChemicalEntity/*.parquet"
# Table count: 64, Sub-table count: 122
# COPY produces_NamedThing_PhenotypicFeature FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/NamedThing_PhenotypicFeature/*.parquet"
# Table count: 64, Sub-table count: 123
# COPY produces_Disease_AnatomicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Disease_AnatomicalEntity/*.parquet"
# Table count: 64, Sub-table count: 124
# COPY produces_Phenomenon_GenomicEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Phenomenon_GenomicEntity/*.parquet"
# Table count: 64, Sub-table count: 125
# COPY produces_OrganismTaxon_ChemicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/OrganismTaxon_ChemicalEntity/*.parquet"
# Table count: 64, Sub-table count: 126
# COPY produces_AnatomicalEntity_Protein FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/AnatomicalEntity_Protein/*.parquet"
# Table count: 64, Sub-table count: 127
# COPY produces_Gene_Protein FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Gene_Protein/*.parquet"
# Table count: 64, Sub-table count: 128
# COPY produces_GenomicEntity_ChemicalMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GenomicEntity_ChemicalMixture/*.parquet"
# Table count: 64, Sub-table count: 129
# COPY produces_Cell_MolecularActivity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Cell_MolecularActivity/*.parquet"
# Table count: 64, Sub-table count: 130
# COPY produces_ChemicalMixture_ChemicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/ChemicalMixture_ChemicalEntity/*.parquet"
# Table count: 64, Sub-table count: 131
# COPY produces_Disease_SmallMolecule FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Disease_SmallMolecule/*.parquet"
# Table count: 64, Sub-table count: 132
# COPY produces_Disease_MolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Disease_MolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 133
# COPY produces_Protein_PhysicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Protein_PhysicalEntity/*.parquet"
# Table count: 64, Sub-table count: 134
# COPY produces_Polypeptide_Protein FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Polypeptide_Protein/*.parquet"
# Table count: 64, Sub-table count: 135
# COPY produces_Gene_ComplexMolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Gene_ComplexMolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 136
# COPY produces_MolecularMixture_GrossAnatomicalStructure FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/MolecularMixture_GrossAnatomicalStructure/*.parquet"
# Table count: 64, Sub-table count: 137
# COPY produces_AnatomicalEntity_NucleicAcidEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/AnatomicalEntity_NucleicAcidEntity/*.parquet"
# Table count: 64, Sub-table count: 138
# COPY produces_Gene_NucleicAcidEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Gene_NucleicAcidEntity/*.parquet"
# Table count: 64, Sub-table count: 139
# COPY produces_OrganismTaxon_SmallMolecule FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/OrganismTaxon_SmallMolecule/*.parquet"
# Table count: 64, Sub-table count: 140
# COPY produces_ComplexMolecularMixture_AnatomicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/ComplexMolecularMixture_AnatomicalEntity/*.parquet"
# Table count: 64, Sub-table count: 141
# COPY produces_Protein_Food FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Protein_Food/*.parquet"
# Table count: 64, Sub-table count: 142
# COPY produces_Activity_PhenotypicFeature FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Activity_PhenotypicFeature/*.parquet"
# Table count: 64, Sub-table count: 143
# COPY produces_GeneticInheritance_Drug FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GeneticInheritance_Drug/*.parquet"
# Table count: 64, Sub-table count: 144
# COPY produces_Gene_BiologicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Gene_BiologicalEntity/*.parquet"
# Table count: 64, Sub-table count: 145
# COPY produces_GrossAnatomicalStructure_GenomicEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GrossAnatomicalStructure_GenomicEntity/*.parquet"
# Table count: 64, Sub-table count: 146
# COPY produces_Gene_Food FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Gene_Food/*.parquet"
# Table count: 64, Sub-table count: 147
# COPY produces_NucleicAcidEntity_GenomicEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/NucleicAcidEntity_GenomicEntity/*.parquet"
# Table count: 64, Sub-table count: 148
# COPY produces_PhysiologicalProcess_Food FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/PhysiologicalProcess_Food/*.parquet"
# Table count: 64, Sub-table count: 149
# COPY produces_Phenomenon_MolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Phenomenon_MolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 150
# COPY produces_Procedure_NucleicAcidEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Procedure_NucleicAcidEntity/*.parquet"
# Table count: 64, Sub-table count: 151
# COPY produces_CellularComponent_Polypeptide FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/CellularComponent_Polypeptide/*.parquet"
# Table count: 64, Sub-table count: 152
# COPY produces_GrossAnatomicalStructure_InformationContentEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GrossAnatomicalStructure_InformationContentEntity/*.parquet"
# Table count: 64, Sub-table count: 153
# COPY produces_OrganismTaxon_ChemicalMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/OrganismTaxon_ChemicalMixture/*.parquet"
# Table count: 64, Sub-table count: 154
# COPY produces_Food_ChemicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Food_ChemicalEntity/*.parquet"
# Table count: 64, Sub-table count: 155
# COPY produces_ClinicalAttribute_ChemicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/ClinicalAttribute_ChemicalEntity/*.parquet"
# Table count: 64, Sub-table count: 156
# COPY produces_MolecularActivity_NucleicAcidEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/MolecularActivity_NucleicAcidEntity/*.parquet"
# Table count: 64, Sub-table count: 157
# COPY produces_PhysiologicalProcess_MolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/PhysiologicalProcess_MolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 158
# COPY produces_PhysiologicalProcess_ComplexMolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/PhysiologicalProcess_ComplexMolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 159
# COPY produces_SmallMolecule_NamedThing FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/SmallMolecule_NamedThing/*.parquet"
# Table count: 64, Sub-table count: 160
# COPY produces_PhysiologicalProcess_Drug FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/PhysiologicalProcess_Drug/*.parquet"
# Table count: 64, Sub-table count: 161
# COPY produces_AnatomicalEntity_PhysicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/AnatomicalEntity_PhysicalEntity/*.parquet"
# Table count: 64, Sub-table count: 162
# COPY produces_NamedThing_SmallMolecule FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/NamedThing_SmallMolecule/*.parquet"
# Table count: 64, Sub-table count: 163
# COPY produces_InformationContentEntity_Gene FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/InformationContentEntity_Gene/*.parquet"
# Table count: 64, Sub-table count: 164
# COPY produces_GrossAnatomicalStructure_ChemicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GrossAnatomicalStructure_ChemicalEntity/*.parquet"
# Table count: 64, Sub-table count: 165
# COPY produces_GeneticInheritance_Food FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GeneticInheritance_Food/*.parquet"
# Table count: 64, Sub-table count: 166
# COPY produces_Gene_Drug FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Gene_Drug/*.parquet"
# Table count: 64, Sub-table count: 167
# COPY produces_Cell_Disease FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Cell_Disease/*.parquet"
# Table count: 64, Sub-table count: 168
# COPY produces_NucleicAcidEntity_SmallMolecule FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/NucleicAcidEntity_SmallMolecule/*.parquet"
# Table count: 64, Sub-table count: 169
# COPY produces_MolecularMixture_NamedThing FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/MolecularMixture_NamedThing/*.parquet"
# Table count: 64, Sub-table count: 170
# COPY produces_PopulationOfIndividualOrganisms_Cell FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/PopulationOfIndividualOrganisms_Cell/*.parquet"
# Table count: 64, Sub-table count: 171
# COPY produces_PhenotypicFeature_Device FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/PhenotypicFeature_Device/*.parquet"
# Table count: 64, Sub-table count: 172
# COPY produces_CellularComponent_PhenotypicFeature FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/CellularComponent_PhenotypicFeature/*.parquet"
# Table count: 64, Sub-table count: 173
# COPY produces_Disease_Polypeptide FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Disease_Polypeptide/*.parquet"
# Table count: 64, Sub-table count: 174
# COPY produces_PopulationOfIndividualOrganisms_ChemicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/PopulationOfIndividualOrganisms_ChemicalEntity/*.parquet"
# Table count: 64, Sub-table count: 175
# COPY produces_InformationContentEntity_ChemicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/InformationContentEntity_ChemicalEntity/*.parquet"
# Table count: 64, Sub-table count: 176
# COPY produces_CellularComponent_MolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/CellularComponent_MolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 177
# COPY produces_GrossAnatomicalStructure_SmallMolecule FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GrossAnatomicalStructure_SmallMolecule/*.parquet"
# Table count: 64, Sub-table count: 178
# COPY produces_SmallMolecule_ChemicalMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/SmallMolecule_ChemicalMixture/*.parquet"
# Table count: 64, Sub-table count: 179
# COPY produces_OrganismTaxon_GenomicEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/OrganismTaxon_GenomicEntity/*.parquet"
# Table count: 64, Sub-table count: 180
# COPY produces_PhysiologicalProcess_Device FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/PhysiologicalProcess_Device/*.parquet"
# Table count: 64, Sub-table count: 181
# COPY produces_Gene_NamedThing FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Gene_NamedThing/*.parquet"
# Table count: 64, Sub-table count: 182
# COPY produces_ComplexMolecularMixture_Gene FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/ComplexMolecularMixture_Gene/*.parquet"
# Table count: 64, Sub-table count: 183
# COPY produces_Device_ComplexMolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Device_ComplexMolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 184
# COPY produces_Cell_NucleicAcidEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Cell_NucleicAcidEntity/*.parquet"
# Table count: 64, Sub-table count: 185
# COPY produces_GeneticInheritance_Polypeptide FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/GeneticInheritance_Polypeptide/*.parquet"
# Table count: 64, Sub-table count: 186
# COPY produces_MolecularMixture_Device FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/MolecularMixture_Device/*.parquet"
# Table count: 64, Sub-table count: 187
# COPY produces_OrganismAttribute_BiologicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/OrganismAttribute_BiologicalEntity/*.parquet"
# Table count: 64, Sub-table count: 188
# COPY produces_ChemicalEntity_PhysicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/ChemicalEntity_PhysicalEntity/*.parquet"
# Table count: 64, Sub-table count: 189
# COPY produces_Phenomenon_Protein FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Phenomenon_Protein/*.parquet"
# Table count: 64, Sub-table count: 190
# COPY produces_Drug_ComplexMolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Drug_ComplexMolecularMixture/*.parquet"
# Table count: 64, Sub-table count: 191
# COPY produces_MolecularActivity_ChemicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/MolecularActivity_ChemicalEntity/*.parquet"
# Table count: 64, Sub-table count: 192
# COPY produces_Cell_Device FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Cell_Device/*.parquet"
# Table count: 64, Sub-table count: 193
# COPY produces_Protein_Drug FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/Protein_Drug/*.parquet"
# Table count: 64, Sub-table count: 194
# COPY produces_SmallMolecule_BiologicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/SmallMolecule_BiologicalEntity/*.parquet"
# Table count: 64, Sub-table count: 195
# COPY produces_ComplexMolecularMixture_Protein FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/ComplexMolecularMixture_Protein/*.parquet"
# Table count: 64, Sub-table count: 196
# COPY produces_NamedThing_Polypeptide FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/produces/NamedThing_Polypeptide/*.parquet"
# Table count: 64, Sub-table count: 197
# ...
# Table count: 124, Sub-table count: 1087
# COPY affects_Activity_BiologicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/affects/Activity_BiologicalEntity/*.parquet"
# Table count: 124, Sub-table count: 1088
# COPY affects_Disease_Drug FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/affects/Disease_Drug/*.parquet"
# Table count: 124, Sub-table count: 1089
# COPY affects_Device_Procedure FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/affects/Device_Procedure/*.parquet"
# Table count: 124, Sub-table count: 1090
# COPY affects_ClinicalAttribute_NamedThing FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/affects/ClinicalAttribute_NamedThing/*.parquet"
# Table count: 124, Sub-table count: 1091
# COPY affects_ChemicalEntity_Disease FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/affects/ChemicalEntity_Disease/*.parquet"
# Table count: 124, Sub-table count: 1092
# COPY affects_Device_InformationContentEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/affects/Device_InformationContentEntity/*.parquet"
# Table count: 124, Sub-table count: 1093
# COPY affects_NamedThing_PopulationOfIndividualOrganisms FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/affects/NamedThing_PopulationOfIndividualOrganisms/*.parquet"
# Table count: 124, Sub-table count: 1094
# COPY affects_PhysiologicalProcess_SmallMolecule FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/affects/PhysiologicalProcess_SmallMolecule/*.parquet"
# Table count: 124, Sub-table count: 1095
# COPY affects_ChemicalMixture_Device FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/affects/ChemicalMixture_Device/*.parquet"
# Table count: 124, Sub-table count: 1096
# COPY affects_MolecularMixture_BiologicalProcess FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/affects/MolecularMixture_BiologicalProcess/*.parquet"
# Table count: 124, Sub-table count: 1097
# COPY affects_Protein_ClinicalAttribute FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/affects/Protein_ClinicalAttribute/*.parquet"
# Table count: 124, Sub-table count: 1098
# COPY affects_Phenomenon_PhenotypicFeature FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/affects/Phenomenon_PhenotypicFeature/*.parquet"
# Table count: 124, Sub-table count: 1099
# COPY affects_SmallMolecule_ProteinFamily FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/affects/SmallMolecule_ProteinFamily/*.parquet"
# Table count: 124, Sub-table count: 1100
# COPY affects_OrganismTaxon_Disease FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/affects/OrganismTaxon_Disease/*.parquet"
# Table count: 124, Sub-table count: 1101
# COPY affects_PhysiologicalProcess_OrganismAttribute FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/affects/PhysiologicalProcess_OrganismAttribute/*.parquet"
# Table count: 124, Sub-table count: 1102
# COPY affects_IndividualOrganism_Food FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/affects/IndividualOrganism_Food/*.parquet"
# Table count: 124, Sub-table count: 1103
# COPY has_molecular_consequence FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_molecular_consequence/Gene_InformationContentEntity/*.parquet"
# Table count: 125, Sub-table count: 1
# COPY indirectly_physically_interacts_with_Cell_Cell FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/indirectly_physically_interacts_with/Cell_Cell/*.parquet"
# Table count: 126, Sub-table count: 1
# COPY indirectly_physically_interacts_with_Cell_GrossAnatomicalStructure FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/indirectly_physically_interacts_with/Cell_GrossAnatomicalStructure/*.parquet"
# Table count: 126, Sub-table count: 2
# COPY indirectly_physically_interacts_with_NamedThing_NamedThing FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/indirectly_physically_interacts_with/NamedThing_NamedThing/*.parquet"
# Table count: 126, Sub-table count: 3
# COPY directly_physically_interacts_with_Gene_Protein FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/directly_physically_interacts_with/Gene_Protein/*.parquet"
# Table count: 127, Sub-table count: 1
# COPY directly_physically_interacts_with_MolecularActivity_MolecularActivity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/directly_physically_interacts_with/MolecularActivity_MolecularActivity/*.parquet"
# Table count: 127, Sub-table count: 2
# COPY directly_physically_interacts_with_Protein_Protein FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/directly_physically_interacts_with/Protein_Protein/*.parquet"
# Table count: 127, Sub-table count: 3
# COPY directly_physically_interacts_with_SmallMolecule_Gene FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/directly_physically_interacts_with/SmallMolecule_Gene/*.parquet"
# Table count: 127, Sub-table count: 4
# COPY directly_physically_interacts_with_ChemicalEntity_Gene FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/directly_physically_interacts_with/ChemicalEntity_Gene/*.parquet"
# Table count: 127, Sub-table count: 5
# COPY directly_physically_interacts_with_Cell_Gene FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/directly_physically_interacts_with/Cell_Gene/*.parquet"
# Table count: 127, Sub-table count: 6
# COPY directly_physically_interacts_with_ChemicalEntity_Protein FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/directly_physically_interacts_with/ChemicalEntity_Protein/*.parquet"
# Table count: 127, Sub-table count: 7
# COPY directly_physically_interacts_with_MolecularMixture_Protein FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/directly_physically_interacts_with/MolecularMixture_Protein/*.parquet"
# Table count: 127, Sub-table count: 8
# COPY directly_physically_interacts_with_Drug_Gene FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/directly_physically_interacts_with/Drug_Gene/*.parquet"
# Table count: 127, Sub-table count: 9
# COPY directly_physically_interacts_with_MolecularMixture_Gene FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/directly_physically_interacts_with/MolecularMixture_Gene/*.parquet"
# Table count: 127, Sub-table count: 10
# COPY directly_physically_interacts_with_SmallMolecule_Protein FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/directly_physically_interacts_with/SmallMolecule_Protein/*.parquet"
# Table count: 127, Sub-table count: 11
# COPY directly_physically_interacts_with_Protein_Gene FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/directly_physically_interacts_with/Protein_Gene/*.parquet"
# Table count: 127, Sub-table count: 12
# COPY directly_physically_interacts_with_Gene_Gene FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/directly_physically_interacts_with/Gene_Gene/*.parquet"
# Table count: 127, Sub-table count: 13
# COPY has_output_BiologicalProcess_ChemicalMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/BiologicalProcess_ChemicalMixture/*.parquet"
# Table count: 128, Sub-table count: 1
# COPY has_output_MolecularActivity_Gene FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/MolecularActivity_Gene/*.parquet"
# Table count: 128, Sub-table count: 2
# COPY has_output_BiologicalProcess_Protein FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/BiologicalProcess_Protein/*.parquet"
# Table count: 128, Sub-table count: 3
# COPY has_output_BiologicalProcess_SmallMolecule FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/BiologicalProcess_SmallMolecule/*.parquet"
# Table count: 128, Sub-table count: 4
# COPY has_output_NamedThing_InformationContentEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/NamedThing_InformationContentEntity/*.parquet"
# Table count: 128, Sub-table count: 5
# COPY has_output_MolecularActivity_MolecularEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/MolecularActivity_MolecularEntity/*.parquet"
# Table count: 128, Sub-table count: 6
# COPY has_output_BiologicalProcess_Polypeptide FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/BiologicalProcess_Polypeptide/*.parquet"
# Table count: 128, Sub-table count: 7
# COPY has_output_PhysiologicalProcess_Cell FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/PhysiologicalProcess_Cell/*.parquet"
# Table count: 128, Sub-table count: 8
# COPY has_output_MolecularActivity_NamedThing FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/MolecularActivity_NamedThing/*.parquet"
# Table count: 128, Sub-table count: 9
# COPY has_output_BiologicalProcess_Gene FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/BiologicalProcess_Gene/*.parquet"
# Table count: 128, Sub-table count: 10
# COPY has_output_BiologicalProcess_PhenotypicFeature FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/BiologicalProcess_PhenotypicFeature/*.parquet"
# Table count: 128, Sub-table count: 11
# COPY has_output_NamedThing_PhysicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/NamedThing_PhysicalEntity/*.parquet"
# Table count: 128, Sub-table count: 12
# COPY has_output_EnvironmentalProcess_NamedThing FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/EnvironmentalProcess_NamedThing/*.parquet"
# Table count: 128, Sub-table count: 13
# COPY has_output_MolecularActivity_NucleicAcidEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/MolecularActivity_NucleicAcidEntity/*.parquet"
# Table count: 128, Sub-table count: 14
# COPY has_output_MolecularActivity_ChemicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/MolecularActivity_ChemicalEntity/*.parquet"
# Table count: 128, Sub-table count: 15
# COPY has_output_InformationContentEntity_SmallMolecule FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/InformationContentEntity_SmallMolecule/*.parquet"
# Table count: 128, Sub-table count: 16
# COPY has_output_BiologicalProcess_GrossAnatomicalStructure FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/BiologicalProcess_GrossAnatomicalStructure/*.parquet"
# Table count: 128, Sub-table count: 17
# COPY has_output_MolecularActivity_Polypeptide FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/MolecularActivity_Polypeptide/*.parquet"
# Table count: 128, Sub-table count: 18
# COPY has_output_PhysiologicalProcess_AnatomicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/PhysiologicalProcess_AnatomicalEntity/*.parquet"
# Table count: 128, Sub-table count: 19
# COPY has_output_BiologicalProcess_CellularComponent FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/BiologicalProcess_CellularComponent/*.parquet"
# Table count: 128, Sub-table count: 20
# COPY has_output_BiologicalProcess_MolecularEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/BiologicalProcess_MolecularEntity/*.parquet"
# Table count: 128, Sub-table count: 21
# COPY has_output_EnvironmentalProcess_PhysicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/EnvironmentalProcess_PhysicalEntity/*.parquet"
# Table count: 128, Sub-table count: 22
# COPY has_output_BiologicalProcess_Drug FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/BiologicalProcess_Drug/*.parquet"
# Table count: 128, Sub-table count: 23
# COPY has_output_MolecularActivity_Protein FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/MolecularActivity_Protein/*.parquet"
# Table count: 128, Sub-table count: 24
# COPY has_output_InformationContentEntity_BiologicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/InformationContentEntity_BiologicalEntity/*.parquet"
# Table count: 128, Sub-table count: 25
# COPY has_output_MolecularActivity_Drug FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/MolecularActivity_Drug/*.parquet"
# Table count: 128, Sub-table count: 26
# COPY has_output_BiologicalProcess_BiologicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/BiologicalProcess_BiologicalEntity/*.parquet"
# Table count: 128, Sub-table count: 27
# COPY has_output_Activity_AnatomicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/Activity_AnatomicalEntity/*.parquet"
# Table count: 128, Sub-table count: 28
# COPY has_output_MolecularActivity_MolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/MolecularActivity_MolecularMixture/*.parquet"
# Table count: 128, Sub-table count: 29
# COPY has_output_BiologicalProcess_NamedThing FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/BiologicalProcess_NamedThing/*.parquet"
# Table count: 128, Sub-table count: 30
# COPY has_output_MolecularActivity_SmallMolecule FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/MolecularActivity_SmallMolecule/*.parquet"
# Table count: 128, Sub-table count: 31
# COPY has_output_BiologicalProcess_PhysicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/BiologicalProcess_PhysicalEntity/*.parquet"
# Table count: 128, Sub-table count: 32
# COPY has_output_BiologicalProcess_Cell FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/BiologicalProcess_Cell/*.parquet"
# Table count: 128, Sub-table count: 33
# COPY has_output_PhysiologicalProcess_GrossAnatomicalStructure FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/PhysiologicalProcess_GrossAnatomicalStructure/*.parquet"
# Table count: 128, Sub-table count: 34
# COPY has_output_BiologicalProcess_RNAProduct FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/BiologicalProcess_RNAProduct/*.parquet"
# Table count: 128, Sub-table count: 35
# COPY has_output_PathologicalProcess_GrossAnatomicalStructure FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/PathologicalProcess_GrossAnatomicalStructure/*.parquet"
# Table count: 128, Sub-table count: 36
# COPY has_output_BiologicalProcess_ChemicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/BiologicalProcess_ChemicalEntity/*.parquet"
# Table count: 128, Sub-table count: 37
# COPY has_output_MolecularActivity_BiologicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/MolecularActivity_BiologicalEntity/*.parquet"
# Table count: 128, Sub-table count: 38
# COPY has_output_BiologicalProcess_MolecularMixture FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/BiologicalProcess_MolecularMixture/*.parquet"
# Table count: 128, Sub-table count: 39
# COPY has_output_BiologicalProcess_AnatomicalEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/BiologicalProcess_AnatomicalEntity/*.parquet"
# Table count: 128, Sub-table count: 40
# COPY has_output_BiologicalProcess_NucleicAcidEntity FROM "../data/kg2c_lite_2.8.4.full.with-metanames.dataset.parquet/edges/has_output/BiologicalProcess_NucleicAcidEntity/*.parquet"
# Table count: 128, Sub-table count: 41
# Finished running Kuzu COPY statements.
